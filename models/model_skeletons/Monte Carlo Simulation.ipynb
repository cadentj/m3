# %% [markdown]
# What is a Monte Carlo Simulation?
#
# A for loop with a couple of inputs that runs a probability a bunch of times and spits out an averaged output.
#
# General format is:
#
# 1. Number of iterations
# 2. Simulation
# - Returns a probability for that iteration
# - Might return a value that is dependent on that probability.
#  - Ex. A end balance for a gambling simulator with set win/loss $
#
# CJ

# %%
# Inputs

# Outputs (tracking)

probability = []

# %%
# HP
iterations = 1000000

# %%
# Define random function here
# Ex. Productivity has a 22% increase with a STD of 50% --> negative values account for lost work. Randomize choices on that scale and return a value that is plugged into a function

# %%
for i in range(iterations) :


    # Throw in function with random variable below
    result = 

    probability.append(result)

# %%
avg_probability = sum(probability)/len(probability)

print(f"Probability: {avg_probability}")
